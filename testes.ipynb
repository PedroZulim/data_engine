# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Data.csv', sep=',')

# %%
df
# Out:
#      firt name                           last name  \
# 0        W#ndy                              V3n33r
# 1     J#ss@l!n                                 NaN
# 2         N$@m                      D\uFFFD\uFFFDr
# 3     C$ll#tt#                          Sm\u2066rt
# 4        M#rcy                           S$wbr$dg$
# ..         ...                                 ...
# 995      K#lby                              Pl$tts
# 996      J%n!@  Al\u2066ls\u2066ndr\u2066v\u2066ch
# 997       T@n@                           D33rn3l3y
# 998  S#b@st!#n                             G$r$w$y
# 999     V!v!#n             L\uFFFD\uFFFDghr\uFFFDy
#
#                                 email date of birth         phone number  \
# 0                   wvnr0@jiathis.com     2/25/1978   +60 (713) 447.6315
# 1               jsomersett1@cisco,com    05-26-1979  +385 (962) 935-5565
# 2              ndufffdufffdr2@home_pl           NaN    +1 (816) 214-3377
# ...

# %%
dfnew = pd.read_csv('./fix_to_surname.csv', sep=';')

# %%
df['last name'] = dfnew['last name']

# %%
df2 = df

# %%
df2['firt name'] = df['firt name'].str.replace('#','e').str.replace('@','a').str.replace('!','i').str.replace('$','o').str.replace('%','a').str.replace('-',' ')

# %%
df2['last name'] = df['last name'].str.replace('😀','o').str.replace('😂','u').str.replace('�','i').str.replace('$','e').str.replace('.','').str.replace('3','a').str.capitalize()

# %%
df2
# Out:
#      firt name     last name                             email date of birth  \
# 0        Wendy        Brough                 wvnr0@jiathis.com     2/25/1978
# 1     Jessalin        O'hare             jsomersett1@cisco,com    05-26-1979
# 2         Noam        Bowton            ndufffdufffdr2@home_pl           NaN
# 3     Collette       Hallede                               NaN    12-17-1974
# 4        Mercy         Tatum                               NaN    1982/06/25
# ..         ...           ...                               ...           ...
# 995      Kelby      Brimelow                               NaN      6/6/1973
# 996      Jania          Oran      jalulsundruvuchro$oracle.com    06-24-1984
# 997       Tana  De bernardis                 tdrnlyrp@admin.ch    1983/02/28
# 998  Sebastien        Harlow             sgrwyrq@bloomberg,com    1987/07/21
# 999     Vivien       Belward  vlufffdufffdghrufffdyrr@etsy,com    1974/01/31
#
# ...

# %%
df2['email'] = df['email'].replace(np.nan, 'UNDEFINED').str.replace('$','@').str.replace(',com','.com')

# %%
df2['email']
# Out:
# 0                     wvnr0@jiathis.com
# 1                 jsomersett1@cisco.com
# 2                ndufffdufffdr2@home_pl
# 3                             UNDEFINED
# 4                             UNDEFINED
#                      ...
# 995                           UNDEFINED
# 996        jalulsundruvuchro@oracle.com
# 997                   tdrnlyrp@admin.ch
# 998               sgrwyrq@bloomberg.com
# 999    vlufffdufffdghrufffdyrr@etsy.com
# Name: email, Length: 1000, dtype: object

# %%
df2['postal code'] = df['postal code'].replace(np.nan, 'UNDEFINED')

# %%
df2
